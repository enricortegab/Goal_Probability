# %%
import torch
from torch.utils.data import Dataset
from PIL import Image
import pandas as pd
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt 
import os 


class GoalDataset(Dataset):
    def __init__(self, dataframe,transform=None):
        self.data = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = self.data.iloc[idx, 0]
        label = int(self.data.iloc[idx, 1])
        image = Image.open(img_path).convert('RGB')
        coeficient=self.data.iloc[idx,2]

        if self.transform:
            image = self.transform(image)

        return image, label, coeficient

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA L40S-12C

# %%
import os
import pandas as pd

def create_dataframe_shot_only(dataset_root):
    rows = []

    for shot_folder in os.listdir(dataset_root):
        folder_path = os.path.join(dataset_root, shot_folder)
        if not os.path.isdir(folder_path):
            continue

        label_path = os.path.join(folder_path, "label.txt")
        if not os.path.exists(label_path):
            print(f"Etiqueta no encontrada en {folder_path}")
            continue
        
        try:
            with open(label_path, "r") as f:
                lines = f.readlines()
                label = int(lines[0].strip())  # Solo la primera línea para el label
                
                # Buscamos coeficient_AMET en las siguientes líneas
                coeficient_AMET = None
                for line in lines[1:]:
                    if 'frame_shot.jpg' in line:
                        coeficient_AMET = float(line.split(':')[-1].strip())
                        break
                
                if coeficient_AMET is None:
                    # Si no encontramos coeficient_AMET, saltamos esta carpeta
                    print(f"No se encontró coeficient_AMET en {folder_path}")
                    continue

        except ValueError:
            print(f"Etiqueta inválida o coeficiente no válido en {folder_path}")
            continue

        shot_img_path = os.path.join(folder_path, "frame_shot.jpg")
        if os.path.exists(shot_img_path):
            rows.append([shot_img_path, label, coeficient_AMET])
        else:
            print(f"Frame shot no trobat en {folder_path}")

    df = pd.DataFrame(rows, columns=["image_path", "label", "coeficient_Amet"])
    return df

dataset_path= "./Frames_Bons_Definitius_TM"
df = create_dataframe_shot_only(dataset_path)

Data = GoalDataset(df)
# Out:
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_17-00_Real_Madrid_1_-_0_Granada_CF_1_224p_shot_777
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-11_-_17-30_Darmstadt_2_-_1_Dortmund_2_224p_shot_416
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-15_-_22-45_Real_Madrid_3_-_1_Napoli_2_224p_shot_472
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-26_-_18-15_Atl._Madrid_1_-_2_Barcelona_1_224p_shot_930
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-26_-_22-45_Villarreal_2_-_3_Real_Madrid_2_224p_shot_1555
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-27_-_23-00_Leicester_3_-_1_Liverpool_1_224p_shot_1774
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-04_-_17-00_AS_Roma_1_-_2_Napoli_2_224p_shot_2324
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-04_-_19-00_Paris_SG_1_-_0_Nancy_2_224p_shot_716
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-08_-_22-45_Barcelona_6_-_1_Paris_SG_1_224p_shot_574
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-12_-_18-15_Dep._La_Coruna_2_-_1_Barcelona_1_224p_shot_533
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-19_-_22-45_AS_Roma_3_-_1_Sassuolo_1_224p_shot_171
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-19_-_23-00_Paris_SG_2_-_1_Lyon_2_224p_shot_1532
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-02_-_17-15_Real_Madrid_3_-_0_Alaves_1_224p_shot_1813
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-09_-_18-00_Everton_4_-_2_Leicester_1_224p_shot_238
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-04_-_22-45_Real_Madrid_1_-_0_Liverpool_1_224p_shot_2588
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-22_-_16-30_Hoffenheim_1_-_2_Bayern_Munich_2_224p_shot_277
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-05_-_22-45_Manchester_City_1_-_2_CSKA_Moscow_1_224p_shot_1273
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-16_-_19-00_Inter_1_-_2_Juventus_2_224p_shot_1193
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-09_-_22-45_Galatasaray_1_-_4_Arsenal_1_224p_shot_2403
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-18_-_19-30_Metz_2_-_3_Paris_SG_2_224p_shot_2482
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-22_-_18-00_Paris_SG_2_-_0_Montpellier_2_224p_shot_1981
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-26_-_22-30_Dep._La_Coruna_2_-_6_Real_Madrid_1_224p_shot_1390
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-02_-_21-45_Real_Madrid_3_-_0_Atl._Madrid_2_224p_shot_2685
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-17_-_22-45_Shakhtar_Donetsk_0_-_0_Bayern_Munich_1_224p_shot_94
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-25_-_22-45_Arsenal_1_-_3_Monaco_1_224p_shot_2258
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-10_-_22-45_Real_Madrid_3_-_4_Schalke_2_224p_shot_1115
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-06_-_19-00_Napoli_3_-_1_Cagliari_2_224p_shot_2785
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-05_-_22-00_Marseille_2_-_3_Paris_SG_2_224p_shot_114
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-22_-_21-45_Real_Madrid_1_-_0_Atl._Madrid_1_224p_shot_894
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-02_-_17-00_Cordoba_0_-_8_Barcelona_2_224p_shot_2529
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-05_-_21-45_Juventus_2_-_1_Real_Madrid_1_224p_shot_472
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia_1_224p_shot_2361
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-10_-_21-45_Lazio_1_-_2_Inter_1_224p_shot_125
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-23_-_19-30_Barcelona_2_-_2_Dep._La_Coruna_2_224p_shot_1134
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Liverpool_0_-_3_West_Ham_2_224p_shot_1844
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_21-45_AC_Milan_2_-_1_Empoli_2_224p_shot_2023
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_21-30_Atl._Madrid_1_-_2_Barcelona_1_224p_shot_2066
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Paris_SG_2_-_0_Malmo_FF_1_224p_shot_1131
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-20_-_13-30_Chievo_0_-_1_Inter_1_224p_shot_2464
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Barcelona_2_-_1_Las_Palmas_2_224p_shot_1257
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_18-30_Nantes_1_-_4_Paris_SG_1_224p_shot_1290
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_21-45_Napoli_2_-_1_Juventus_2_224p_shot_217
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Barcelona_2_-_1_Bayer_Leverkusen_1_224p_shot_1300
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-03_-_17-00_Manchester_City_6_-_1_Newcastle_Utd_2_224p_shot_844
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-20_-_21-45_Arsenal_2_-_0_Bayern_Munich_1_224p_shot_1665
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-24_-_16-30_Bayern_Munich_4_-_0_FC_Koln_1_224p_shot_612
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_1_224p_shot_1255
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_Real_Madrid_1_-_0_Paris_SG_2_224p_shot_2836
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Bayern_Munich_5_-_1_Arsenal_2_224p_shot_252
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Lyon_0_-_2_Zenit_Petersburg_2_224p_shot_482
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_18-00_Manchester_United_2_-_0_West_Brom_2_224p_shot_1310
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-21_-_20-15_Real_Madrid_0_-_4_Barcelona_2_224p_shot_817
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Barcelona_6_-_1_AS_Roma_1_224p_shot_1028
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_FC_Porto_0_-_2_Dyn._Kiev_1_224p_shot_135
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_Malmo_FF_0_-_5_Paris_SG_2_224p_shot_2633
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-05_-_20-30_Chelsea_0_-_1_Bournemouth_1_224p_shot_2557
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-12_-_17-30_Bayern_Munich_2_-_0_Ingolstadt_2_224p_shot_1774
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-20_-_18-00_Real_Madrid_1_-_0_Rayo_Vallecano_1_224p_shot_1188
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-20_-_18-00_Real_Madrid_1_-_0_Rayo_Vallecano_2_224p_shot_783
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-24_-_22-30_Betis_1_-_1_Real_Madrid_2_224p_shot_1969
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-03_-_22-45_Watford_0_-_0_Chelsea_1_224p_shot_1918
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-02_-_23-00_Liverpool_3_-_0_Manchester_City_2_224p_shot_1651
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-05_-_18-00_Manchester_City_4_-_0_Aston_Villa_2_224p_shot_2190
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-16_-_19-30_Bayern_Munich_3_-_0_Schalke_2_224p_shot_149
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-05-08_-_18-00_Real_Madrid_3_-_2_Valencia_2_224p_shot_1577
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_17-00_Burnley_2_-_0_Liverpool_1_224p_shot_2298
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_19-15_Barcelona_6_-_2_Betis_1_224p_shot_1528
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-21_-_21-45_Paris_SG_3_-_0_Metz_1_224p_shot_2100
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-27_-_14-30_Tottenham_1_-_1_Liverpool_2_224p_shot_2776
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-10_-_17-00_Arsenal_2_-_1_Southampton_2_224p_shot_1510
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-16_-_21-45_Caen_0_-_6_Paris_SG_2_224p_shot_1271
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_14-00_Leganes_1_-_5_Barcelona_1_224p_shot_1840
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_21-45_Napoli_3_-_1_Bologna_2_224p_shot_1262
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-20_-_21-00_Wolfsburg_1_-_5_Dortmund_2_224p_shot_288
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-21_-_21-45_AS_Roma_4_-_0_Crotone_2_224p_shot_671
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-24_-_21-45_Las_Palmas_2_-_2_Real_Madrid_2_224p_shot_1185
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-02_-_17-15_Real_Madrid_1_-_1_Eibar_2_224p_shot_1273
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-14_-_21-30_Dortmund_1_-_1_Hertha_Berlin_2_224p_shot_88
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-15_-_17-15_Barcelona_4_-_0_Dep._La_Coruna_2_224p_shot_1331
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-22_-_16-30_Ingolstadt_3_-_3_Dortmund_1_224p_shot_1864
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-23_-_21-45_AS_Roma_4_-_1_Palermo_1_224p_shot_395
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-29_-_17-00_Tottenham_1_-_1_Leicester_1_224p_shot_2316
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-29_-_19-30_Dortmund_0_-_0_Schalke_2_224p_shot_294
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-06_-_22-45_Paris_SG_4_-_0_Rennes_1_224p_shot_2463
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-19_-_19-00_Paris_SG_2_-_0_Nantes_1_224p_shot_1456
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-20_-_22-45_AC_Milan_2_-_2_Inter_1_224p_shot_2051
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-23_-_22-45_Celtic_0_-_2_Barcelona_2_224p_shot_265
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-26_-_18-00_Liverpool_2_-_0_Sunderland_2_224p_shot_766
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-06_-_22-45_Benfica_1_-_2_Napoli_2_224p_shot_1297
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_20-30_Leicester_4_-_2_Manchester_City_2_224p_shot_635
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-17_-_19-00_Guingamp_2_-_1_Paris_SG_1_224p_shot_1240
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-27_-_20-15_Liverpool_4_-_1_Stoke_City_1_224p_shot_2164
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-08_-_17-00_Genoa_0_-_1_AS_Roma_1_224p_shot_1278
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-15_-_17-00_Napoli_3_-_1_Pescara_2_224p_shot_924
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-22_-_22-45_AS_Roma_1_-_0_Cagliari_2_224p_shot_407
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-29_-_19-30_1._FSV_Mainz_05_1_-_1_Dortmund_1_224p_shot_121
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-10_-_22-45_Napoli_2_-_0_Genoa_1_224p_shot_192
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-08_-_19-30_Chelsea_2_-_2_Swansea_2_224p_shot_2513
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_18-00_Manchester_United_2_-_0_West_Brom_2_224p_shot_1642
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_20-30_Stoke_City_1_-_0_Chelsea_2_224p_shot_2290
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-08_-_17-30_Dortmund_3_-_2_Schalke_1_224p_shot_2215
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Barcelona_6_-_1_AS_Roma_1_224p_shot_2434
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_Atl._Madrid_2_-_0_Galatasaray_1_224p_shot_1160
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_B._Monchengladbach_4_-_2_Sevilla_2_224p_shot_1076
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_Malmo_FF_0_-_5_Paris_SG_2_224p_shot_815
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-05_-_20-30_Chelsea_0_-_1_Bournemouth_1_224p_shot_841
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-20_-_18-00_Real_Madrid_1_-_0_Rayo_Vallecano_1_224p_shot_2454
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-20_-_18-00_Real_Madrid_1_-_0_Rayo_Vallecano_2_224p_shot_914
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-03_-_22-30_Valencia_2_-_2_Real_Madrid_1_224p_shot_633
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-13_-_22-45_Chelsea_2_-_2_West_Brom_1_224p_shot_1173
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-03_-_22-45_Watford_0_-_0_Chelsea_2_224p_shot_364
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-13_-_20-30_Chelsea_5_-_1_Newcastle_Utd_1_224p_shot_500
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-21_-_18-00_Malaga_1_-_1_Real_Madrid_2_224p_shot_614
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-01_-_22-45_Norwich_1_-_2_Chelsea_1_224p_shot_2742
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-05_-_18-00_Chelsea_1_-_1_Stoke_City_1_224p_shot_1097
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-20_-_22-30_Real_Madrid_4_-_0_Sevilla_1_224p_shot_2098
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-02_-_21-30_Barcelona_1_-_2_Real_Madrid_2_224p_shot_2174
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-09_-_19-30_Manchester_City_2_-_1_West_Brom_1_224p_shot_1684
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-23_-_17-00_Bournemouth_1_-_4_Chelsea_1_224p_shot_294
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_19-15_Barcelona_6_-_2_Betis_1_224p_shot_2501
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-21_-_21-45_Paris_SG_3_-_0_Metz_1_224p_shot_2304
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-27_-_21-15_Real_Madrid_2_-_1_Celta_Vigo_1_224p_shot_2521
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-28_-_21-45_Monaco_3_-_1_Paris_SG_1_224p_shot_1330
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-10_-_17-00_Arsenal_2_-_1_Southampton_2_224p_shot_2278
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-16_-_21-45_Caen_0_-_6_Paris_SG_2_224p_shot_693
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_14-00_Leganes_1_-_5_Barcelona_1_224p_shot_430
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_21-45_Napoli_3_-_1_Bologna_2_224p_shot_294
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-21_-_21-45_Genoa_0_-_0_Napoli_1_224p_shot_1083
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-24_-_14-30_Manchester_United_4_-_1_Leicester_1_224p_shot_2161
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-24_-_21-45_Las_Palmas_2_-_2_Real_Madrid_2_224p_shot_2587
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-15_-_17-15_Barcelona_4_-_0_Dep._La_Coruna_2_224p_shot_1531
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-19_-_21-45_Paris_SG_3_-_0_Basel_1_224p_shot_1438
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-22_-_16-30_Ingolstadt_3_-_3_Dortmund_1_224p_shot_2435
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-23_-_21-45_AS_Roma_4_-_1_Palermo_2_224p_shot_2056
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-26_-_21-45_Napoli_2_-_0_Empoli_2_224p_shot_1435
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-28_-_21-45_Lille_0_-_1_Paris_SG_1_224p_shot_678
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-29_-_19-30_Dortmund_0_-_0_Schalke_2_224p_shot_994
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-06_-_17-00_Palermo_1_-_2_AC_Milan_1_224p_shot_861
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-20_-_22-45_AC_Milan_2_-_2_Inter_1_224p_shot_2379
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_16-30_Bayern_Munich_0_-_1_FC_Augsburg_1_224p_shot_1118
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-23_-_22-45_Napoli_0_-_0_Dyn._Kiev_1_224p_shot_2462
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-26_-_18-15_Real_Madrid_2_-_1_Gijon_1_224p_shot_136
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-27_-_22-45_AS_Roma_3_-_2_Pescara_2_224p_shot_792
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-03_-_17-30_Dortmund_4_-_1_B._Monchengladbach_2_224p_shot_1089
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_17-30_FC_Koln_1_-_1_Dortmund_2_224p_shot_2101
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_22-45_Real_Madrid_3_-_2_Dep._La_Coruna_1_224p_shot_1075
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-08_-_17-00_Genoa_0_-_1_AS_Roma_1_224p_shot_1744
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-08_-_22-45_Villarreal_1_-_1_Barcelona_2_224p_shot_437
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-15_-_17-00_Udinese_0_-_1_AS_Roma_1_224p_shot_1381
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-29_-_14-00_Betis_1_-_1_Barcelona_1_224p_shot_851
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-29_-_19-30_1._FSV_Mainz_05_1_-_1_Dortmund_1_224p_shot_645
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-10_-_22-45_Napoli_2_-_0_Genoa_1_224p_shot_1925
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-11_-_17-30_Darmstadt_2_-_1_Dortmund_1_224p_shot_2494
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-11_-_17-30_Darmstadt_2_-_1_Dortmund_2_224p_shot_740
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-18_-_17-30_Dortmund_3_-_0_Wolfsburg_1_224p_shot_1504
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-19_-_22-45_Barcelona_2_-_1_Leganes_2_224p_shot_1362
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-29_-_16-30_Dortmund_0_-_0_FC_Koln_1_224p_shot_2263
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-14_-_21-00_Real_Madrid_4_-_1_Sevilla_1_224p_shot_573
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-28_-_19-00_AS_Roma_3_-_2_Genoa_1_224p_shot_2077
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-27_-_23-00_Leicester_3_-_1_Liverpool_1_224p_shot_2283
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-01_-_21-30_Barcelona_6_-_1_Gijon_2_224p_shot_2104
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-04_-_17-00_AS_Roma_1_-_2_Napoli_2_224p_shot_2876
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-04_-_22-45_Barcelona_5_-_0_Celta_Vigo_1_224p_shot_1126
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-19_-_22-45_AS_Roma_3_-_1_Sassuolo_1_224p_shot_2249
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-09_-_22-45_Galatasaray_1_-_4_Arsenal_2_224p_shot_1340
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-10_-_22-45_Barcelona_3_-_1_Paris_SG_1_224p_shot_1108
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-18_-_22-45_Schalke_0_-_2_Real_Madrid_2_224p_shot_1563
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-25_-_22-45_Arsenal_1_-_3_Monaco_2_224p_shot_2633
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-10_-_22-45_Real_Madrid_3_-_4_Schalke_2_224p_shot_1543
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-18_-_22-45_Barcelona_1_-_0_Manchester_City_2_224p_shot_1519
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-09_-_22-00_Paris_SG_4_-_0_Guingamp_2_224p_shot_1366
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-12_-_21-45_Bayern_Munich_1_-_2_Real_Madrid_2_224p_shot_2168
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-15_-_16-30_Dortmund_3_-_1_Eintracht_Frankfurt_1_224p_shot_409
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-18_-_19-30_Metz_2_-_3_Paris_SG_2_224p_shot_2838
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-19_-_21-45_Inter_0_-_0_AC_Milan_2_224p_shot_2634
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-25_-_16-30_Dortmund_2_-_0_Eintracht_Frankfurt_1_224p_shot_98
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-26_-_16-00_Torino_2_-_1_Juventus_2_224p_shot_408
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-05_-_21-45_Juventus_2_-_1_Real_Madrid_2_224p_shot_2805
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia_1_224p_shot_2566
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-10_-_21-45_Lazio_1_-_2_Inter_1_224p_shot_1735
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-16_-_19-00_Inter_1_-_2_Juventus_2_224p_shot_2240
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-23_-_19-30_Barcelona_2_-_2_Dep._La_Coruna_2_224p_shot_1750
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-23_-_15-30_West_Brom_2_-_3_Chelsea_1_224p_shot_2294
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Liverpool_0_-_3_West_Ham_2_224p_shot_2780
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_21-45_AC_Milan_2_-_1_Empoli_2_224p_shot_2195
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_21-30_Atl._Madrid_1_-_2_Barcelona_1_224p_shot_51
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Paris_SG_2_-_0_Malmo_FF_1_224p_shot_1958
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Real_Madrid_4_-_0_Shakhtar_Donetsk_2_224p_shot_2123
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_Bayer_Leverkusen_4_-_1_BATE_1_224p_shot_220
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_17-00_Real_Madrid_1_-_0_Granada_CF_2_224p_shot_1191
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-23_-_22-00_Ath_Bilbao_1_-_2_Real_Madrid_2_224p_shot_1618
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_18-30_Nantes_1_-_4_Paris_SG_2_224p_shot_133
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Barcelona_2_-_1_Bayer_Leverkusen_1_224p_shot_2296
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Lyon_0_-_1_Valencia_1_224p_shot_2369
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_1_224p_shot_1371
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_Sevilla_1_-_3_Manchester_City_1_224p_shot_197
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Barcelona_3_-_0_BATE_1_224p_shot_1690
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Bayern_Munich_5_-_1_Arsenal_2_224p_shot_2618
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-05_-_22-45_Ajax_0_-_2_Barcelona_2_224p_shot_1806
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-30_-_16-30_Dortmund_3_-_1_Hertha_Berlin_2_224p_shot_2283
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-28_-_21-45_Lille_0_-_1_Paris_SG_2_224p_shot_1165
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-05_-_22-45_Manchester_City_1_-_2_CSKA_Moscow_2_224p_shot_1144
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-18_-_22-45_Schalke_0_-_2_Real_Madrid_2_224p_shot_2013
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-21_-_18-00_Crystal_Palace_1_-_2_Arsenal_1_224p_shot_273
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-11_-_22-45_Bayern_Munich_7_-_0_Shakhtar_Donetsk_1_224p_shot_1409
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-11_-_17-00_Real_Madrid_3_-_0_Eibar_2_224p_shot_1352
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-21_-_21-45_Barcelona_2_-_0_Paris_SG_2_224p_shot_368
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-25_-_16-30_Dortmund_2_-_0_Eintracht_Frankfurt_2_224p_shot_1536
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-28_-_21-00_Barcelona_6_-_0_Getafe_1_224p_shot_1549
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-02_-_21-00_Sevilla_2_-_3_Real_Madrid_2_224p_shot_2381
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-05_-_21-45_Juventus_2_-_1_Real_Madrid_2_224p_shot_717
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_16-30_Bayern_Munich_0_-_1_FC_Augsburg_1_224p_shot_1391
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-17_-_13-30_Sassuolo_3_-_2_AC_Milan_1_224p_shot_1946
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-23_-_19-30_Barcelona_2_-_2_Dep._La_Coruna_2_224p_shot_827
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-01_-_20-45_Besiktas_1_-_1_Napoli_1_224p_shot_1722
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Manchester_City_2_-_0_Watford_1_224p_shot_1407
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_21-30_Atl._Madrid_1_-_2_Barcelona_2_224p_shot_1994
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_Gent_1_-_1_Lyon_1_224p_shot_537
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_19-30_Manchester_City_1_-_2_West_Ham_2_224p_shot_1042
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-22_-_21-45_Udinese_2_-_3_AC_Milan_2_224p_shot_165
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-23_-_22-00_Ath_Bilbao_1_-_2_Real_Madrid_2_224p_shot_1997
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Barcelona_2_-_1_Las_Palmas_2_224p_shot_518
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_19-15_Real_Madrid_0_-_0_Malaga_2_224p_shot_1510
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-27_-_21-45_Inter_1_-_4_Fiorentina_1_224p_shot_446
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Barcelona_2_-_1_Bayer_Leverkusen_1_224p_shot_300
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Lyon_0_-_1_Valencia_2_224p_shot_2604
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-20_-_21-45_Arsenal_2_-_0_Bayern_Munich_1_224p_shot_2504
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-19_-_23-00_Paris_SG_0_-_0_Toulouse_2_224p_shot_1487
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-27_-_23-00_Leicester_3_-_1_Liverpool_1_224p_shot_2284
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-01_-_21-30_Barcelona_6_-_1_Gijon_2_224p_shot_2512
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_1_224p_shot_1430
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_17-30_Bayern_Munich_4_-_0_VfB_Stuttgart_1_224p_shot_2083
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_18-00_Manchester_United_2_-_0_West_Brom_2_224p_shot_1912
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_20-30_Stoke_City_1_-_0_Chelsea_2_224p_shot_619
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-21_-_20-30_Manchester_City_1_-_4_Liverpool_2_224p_shot_873
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Barcelona_6_-_1_AS_Roma_2_224p_shot_1503
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_FC_Porto_0_-_2_Dyn._Kiev_2_224p_shot_2174
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_B._Monchengladbach_4_-_2_Sevilla_2_224p_shot_1601
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-13_-_22-30_Villarreal_1_-_0_Real_Madrid_1_224p_shot_184
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-13_-_22-45_Chelsea_2_-_2_West_Brom_1_224p_shot_1961
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-03_-_22-45_Watford_0_-_0_Chelsea_2_224p_shot_85
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-13_-_20-30_Chelsea_5_-_1_Newcastle_Utd_2_224p_shot_2593
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-05_-_18-00_Chelsea_1_-_1_Stoke_City_1_224p_shot_895
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-20_-_22-30_Real_Madrid_4_-_0_Sevilla_1_224p_shot_2681
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-02_-_21-30_Barcelona_1_-_2_Real_Madrid_2_224p_shot_383
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-09_-_19-30_Manchester_City_2_-_1_West_Brom_2_224p_shot_1896
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-23_-_17-00_Bournemouth_1_-_4_Chelsea_2_224p_shot_2717
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-05-14_-_18-00_Dep._La_Coruna_0_-_2_Real_Madrid_1_224p_shot_2683
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_19-00_AS_Roma_4_-_0_Udinese_1_224p_shot_1804
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-27_-_21-15_Real_Madrid_2_-_1_Celta_Vigo_2_224p_shot_141
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_21-45_Napoli_3_-_1_Bologna_2_224p_shot_753
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-20_-_21-45_AC_Milan_2_-_0_Lazio_1_224p_shot_2260
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-21_-_23-00_Barcelona_1_-_1_Atl._Madrid_1_224p_shot_1443
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-24_-_21-45_Napoli_2_-_0_Chievo_1_224p_shot_2305
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-19_-_21-45_Paris_SG_3_-_0_Basel_1_224p_shot_1712
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-08_-_22-45_Barcelona_6_-_1_Paris_SG_2_224p_shot_2030
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-12_-_22-45_Palermo_0_-_3_AS_Roma_1_224p_shot_1809
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-09_-_21-45_Lazio_0_-_3_Napoli_1_224p_shot_2542
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-09_-_22-00_Paris_SG_4_-_0_Guingamp_2_224p_shot_2799
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-15_-_16-30_Dortmund_3_-_1_Eintracht_Frankfurt_1_224p_shot_483
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-18_-_21-45_Real_Madrid_4_-_2_Bayern_Munich_1_224p_shot_1632
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-06_-_17-00_Leicester_3_-_0_Watford_1_224p_shot_2456
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-07_-_21-45_AC_Milan_1_-_4_AS_Roma_2_224p_shot_2160
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-23_-_21-45_Paris_SG_0_-_0_Marseille_1_224p_shot_1401
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-14_-_21-45_AS_Roma_3_-_1_Juventus_2_224p_shot_622
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-20_-_21-45_Napoli_4_-_1_Fiorentina_2_224p_shot_1901
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-28_-_19-00_AS_Roma_3_-_2_Genoa_1_224p_shot_2643
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-05_-_22-45_Napoli_1_-_1_Lazio_2_224p_shot_1388
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-06_-_22-45_Paris_SG_4_-_0_Rennes_2_224p_shot_2512
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-19_-_19-00_Paris_SG_2_-_0_Nantes_2_224p_shot_534
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-03_-_18-15_Barcelona_1_-_1_Real_Madrid_1_224p_shot_2172
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-03_-_19-00_Montpellier_3_-_0_Paris_SG_2_224p_shot_1979
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_17-30_FC_Koln_1_-_1_Dortmund_2_224p_shot_284
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_22-45_Real_Madrid_3_-_2_Dep._La_Coruna_1_224p_shot_1677
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-17_-_20-00_AC_Milan_0_-_0_Atalanta_1_224p_shot_1756
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-27_-_20-15_Liverpool_4_-_1_Stoke_City_2_224p_shot_1949
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-14_-_18-15_Barcelona_5_-_0_Las_Palmas_2_224p_shot_2047
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-15_-_17-00_Udinese_0_-_1_AS_Roma_1_224p_shot_2116
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-21_-_19-00_Nantes_0_-_2_Paris_SG_2_224p_shot_30
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-29_-_14-00_Betis_1_-_1_Barcelona_2_224p_shot_2681
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-10_-_22-45_Napoli_2_-_0_Genoa_2_224p_shot_897
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-05_-_22-45_Ajax_0_-_2_Barcelona_2_224p_shot_2020
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-09_-_22-45_Liverpool_1_-_1_Basel_1_224p_shot_745
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-10_-_22-45_Barcelona_3_-_1_Paris_SG_1_224p_shot_2311
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-31_-_20-30_Liverpool_1_-_0_Manchester_City_2_224p_shot_53
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-14_-_20-30_Leicester_0_-_3_Chelsea_1_224p_shot_338
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-15_-_17-00_Udinese_0_-_1_AS_Roma_2_224p_shot_2494
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-31_-_23-00_Liverpool_1_-_1_Chelsea_2_224p_shot_2642
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-31_-_15-45_Chelsea_1_-_3_Liverpool_2_224p_shot_1863
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_1_224p_shot_2347
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_Sevilla_1_-_3_Manchester_City_2_224p_shot_1618
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Bayern_Munich_5_-_1_Arsenal_1_224p_shot_1695
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Gent_1_-_0_Valencia_1_224p_shot_240
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-21_-_17-30_Paderborn_0_-_6_Bayern_Munich_1_224p_shot_1382
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-21_-_18-00_Swansea_2_-_1_Manchester_United_1_224p_shot_1190
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-10_-_22-45_FC_Porto_4_-_0_Basel_1_224p_shot_1843
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-11_-_22-45_Bayern_Munich_7_-_0_Shakhtar_Donetsk_1_224p_shot_1662
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-11_-_19-30_Burnley_0_-_1_Arsenal_1_224p_shot_427
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-21_-_21-45_Bayern_Munich_6_-_1_FC_Porto_2_224p_shot_1981
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-25_-_17-00_Espanyol_0_-_2_Barcelona_1_224p_shot_1477
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-28_-_21-00_Barcelona_6_-_0_Getafe_1_224p_shot_193
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-29_-_21-45_Juventus_3_-_2_Fiorentina_1_224p_shot_2339
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-03_-_21-45_Napoli_3_-_0_AC_Milan_1_224p_shot_230
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia_2_224p_shot_1408
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_16-30_Bayern_Munich_0_-_1_FC_Augsburg_1_224p_shot_1620
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-17_-_13-30_Sassuolo_3_-_2_AC_Milan_1_224p_shot_472
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-08_-_19-30_Chelsea_2_-_2_Swansea_2_224p_shot_775
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Chelsea_1_-_2_Crystal_Palace_1_224p_shot_1132
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Manchester_City_2_-_0_Watford_1_224p_shot_833
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_23-30_Real_Madrid_5_-_0_Betis_1_224p_shot_1293
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Paris_SG_2_-_0_Malmo_FF_2_224p_shot_1091
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-19_-_21-45_Paris_SG_3_-_0_Basel_1_224p_shot_1795
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-22_-_16-30_Ingolstadt_3_-_3_Dortmund_2_224p_shot_944
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-23_-_21-45_Paris_SG_0_-_0_Marseille_2_224p_shot_2210
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-28_-_21-45_Lille_0_-_1_Paris_SG_2_224p_shot_1530
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Bayern_Munich_4_-_0_Olympiakos_Piraeus_1_224p_shot_1619
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_FC_Porto_0_-_2_Dyn._Kiev_2_224p_shot_833
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_B._Monchengladbach_4_-_2_Sevilla_2_224p_shot_2174
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-29_-_15-00_Tottenham_0_-_0_Chelsea_1_224p_shot_1007
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-30_-_17-00_AC_Milan_1_-_0_Pescara_1_224p_shot_2685
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-01_-_22-45_Manchester_City_3_-_1_Barcelona_2_224p_shot_1206
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-05_-_22-45_Napoli_1_-_1_Lazio_2_224p_shot_1761
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-19_-_18-00_Southampton_0_-_0_Liverpool_1_224p_shot_821
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-23_-_22-45_Napoli_0_-_0_Dyn._Kiev_2_224p_shot_597
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-03_-_18-15_Barcelona_1_-_1_Real_Madrid_1_224p_shot_2271
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-04_-_14-30_AC_Milan_2_-_1_Crotone_1_224p_shot_1067
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_Olympiakos_Piraeus_0_-_3_Bayern_Munich_1_224p_shot_2600
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-12_-_21-00_Bastia_0_-_1_Paris_SG_1_224p_shot_2188
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_19-00_AS_Roma_4_-_0_Udinese_2_224p_shot_2121
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-20_-_19-15_Barcelona_6_-_2_Betis_2_224p_shot_269
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-21_-_21-45_Paris_SG_3_-_0_Metz_2_224p_shot_1265
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-27_-_21-45_Napoli_4_-_2_AC_Milan_1_224p_shot_1952
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-28_-_21-45_Monaco_3_-_1_Paris_SG_2_224p_shot_583
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-10_-_21-30_Barcelona_1_-_2_Alaves_1_224p_shot_2300
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-27_-_18-00_Real_Madrid_0_-_1_Atl._Madrid_2_224p_shot_1535
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-02_-_23-00_Levante_1_-_3_Real_Madrid_1_224p_shot_1913
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-05_-_18-00_Real_Madrid_7_-_1_Celta_Vigo_2_224p_shot_1638
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-20_-_22-30_Real_Madrid_4_-_0_Sevilla_2_224p_shot_1097
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_19-30_Manchester_City_1_-_2_West_Ham_2_224p_shot_1371
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-22_-_21-45_Udinese_2_-_3_AC_Milan_2_224p_shot_2677
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-23_-_22-00_Ath_Bilbao_1_-_2_Real_Madrid_2_224p_shot_475
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Leicester_2_-_5_Arsenal_2_224p_shot_1669
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_19-15_Real_Madrid_0_-_0_Malaga_2_224p_shot_622
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-13_-_22-30_Villarreal_1_-_0_Real_Madrid_2_224p_shot_139
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-20_-_18-00_Real_Madrid_1_-_0_Rayo_Vallecano_1_224p_shot_679
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-09_-_22-30_Real_Madrid_5_-_0_Dep._La_Coruna_1_224p_shot_430
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-31_-_19-30_Bayern_Munich_2_-_0_Hoffenheim_2_224p_shot_923
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-16_-_21-45_Sampdoria_0_-_1_AC_Milan_1_224p_shot_319
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-18_-_21-45_Espanyol_0_-_2_Real_Madrid_1_224p_shot_2223
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-21_-_23-00_Barcelona_1_-_1_Atl._Madrid_1_224p_shot_942
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-25_-_21-45_Fiorentina_0_-_0_AC_Milan_2_224p_shot_494
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-02_-_21-45_Celta_Vigo_4_-_3_Barcelona_1_224p_shot_1309
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-27_-_21-45_Inter_1_-_4_Fiorentina_2_224p_shot_1850
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-07_-_22-45_AS_Roma_4_-_0_Fiorentina_2_224p_shot_1789
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-11_-_22-45_Osasuna_1_-_3_Real_Madrid_1_224p_shot_2674
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-18_-_17-30_Dortmund_3_-_0_Wolfsburg_2_224p_shot_2694
# ...
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_19-00_Barcelona_2_-_0_Real_Sociedad_1_224p_shot_2342
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-16_-_19-00_Inter_1_-_2_Juventus_1_224p_shot_1303
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-22_-_16-30_Hoffenheim_1_-_2_Bayern_Munich_2_224p_shot_1222
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_17-00_Liverpool_0_-_3_West_Ham_1_224p_shot_2331
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_21-30_Barcelona_1_-_0_Malaga_2_224p_shot_391
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_Dyn._Kiev_2_-_2_FC_Porto_1_224p_shot_1786
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_14-45_Everton_3_-_1_Chelsea_1_224p_shot_1279
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_17-00_Espanyol_0_-_6_Real_Madrid_2_224p_shot_2105
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Manchester_City_1_-_2_Juventus_2_224p_shot_2131
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_PSV_2_-_1_Manchester_United_2_224p_shot_2683
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_AS_Roma_1_-_1_Barcelona_2_224p_shot_2071
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_16-30_Darmstadt_0_-_3_Bayern_Munich_2_224p_shot_1068
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_18-30_Reims_1_-_1_Paris_SG_2_224p_shot_818
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-20_-_13-30_Chievo_0_-_1_Inter_1_224p_shot_1378
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-20_-_18-30_Dortmund_3_-_0_Bayer_Leverkusen_2_224p_shot_345
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-23_-_22-00_Ath_Bilbao_1_-_2_Real_Madrid_1_224p_shot_2033
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_16-30_1._FSV_Mainz_05_0_-_3_Bayern_Munich_2_224p_shot_781
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Liverpool_3_-_2_Aston_Villa_1_224p_shot_731
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-29_-_21-45_Arsenal_2_-_3_Olympiakos_Piraeus_2_224p_shot_2376
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-03_-_17-00_Manchester_City_6_-_1_Newcastle_Utd_1_224p_shot_661
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_2_224p_shot_2459
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Lyon_0_-_2_Zenit_Petersburg_1_224p_shot_1497
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_20-30_Stoke_City_1_-_0_Chelsea_1_224p_shot_1971
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_22-45_AC_Milan_0_-_0_Atalanta_2_224p_shot_426
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_20-00_Zenit_Petersburg_2_-_0_Valencia_2_224p_shot_2599
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Bayern_Munich_4_-_0_Olympiakos_Piraeus_2_224p_shot_2321
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-29_-_18-00_Eibar_0_-_2_Real_Madrid_1_224p_shot_2405
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-12_-_17-30_Bayern_Munich_2_-_0_Ingolstadt_2_224p_shot_1101
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-19_-_18-00_Chelsea_3_-_1_Sunderland_2_224p_shot_599
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-01-24_-_19-00_Arsenal_0_-_1_Chelsea_1_224p_shot_2528
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-13_-_18-00_Real_Madrid_4_-_2_Ath_Bilbao_2_224p_shot_2128
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-21_-_18-00_Malaga_1_-_1_Real_Madrid_1_224p_shot_1519
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-27_-_18-00_Southampton_1_-_2_Chelsea_2_224p_shot_2578
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-04_-_22-45_Lyon_0_-_2_Zenit_Petersburg_2_224p_shot_1275
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-11-04_-_22-45_Arsenal_3_-_3_Anderlecht_2_224p_shot_1841
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_Dyn._Kiev_2_-_2_FC_Porto_2_224p_shot_1772
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-09_-_22-45_Galatasaray_1_-_4_Arsenal_1_224p_shot_1913
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2014-12-09_-_22-45_Real_Madrid_4_-_0_Ludogorets_1_224p_shot_830
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-17_-_22-45_Shakhtar_Donetsk_0_-_0_Bayern_Munich_1_224p_shot_1842
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-02-25_-_22-45_Arsenal_1_-_3_Monaco_1_224p_shot_1934
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-03-18_-_22-45_Dortmund_0_-_3_Juventus_2_224p_shot_1973
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-11_-_21-45_Verona_0_-_3_Inter_2_224p_shot_2784
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-18_-_21-00_Real_Madrid_3_-_1_Malaga_1_224p_shot_2150
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-04-25_-_21-45_Inter_2_-_1_AS_Roma_2_224p_shot_1769
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-02_-_17-00_Cordoba_0_-_8_Barcelona_2_224p_shot_2355
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-05_-_21-45_Juventus_2_-_1_Real_Madrid_1_224p_shot_470
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_19-00_Barcelona_2_-_0_Real_Sociedad_2_224p_shot_1197
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia_2_224p_shot_2515
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-05-23_-_19-30_Barcelona_2_-_2_Dep._La_Coruna_2_224p_shot_1102
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-22_-_16-30_Hoffenheim_1_-_2_Bayern_Munich_2_224p_shot_1476
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-08-29_-_21-45_AC_Milan_2_-_1_Empoli_2_224p_shot_1092
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-12_-_17-00_Espanyol_0_-_6_Real_Madrid_2_224p_shot_272
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-15_-_21-45_Real_Madrid_4_-_0_Shakhtar_Donetsk_1_224p_shot_754
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-16_-_21-45_AS_Roma_1_-_1_Barcelona_2_224p_shot_2532
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-19_-_17-00_Real_Madrid_1_-_0_Granada_CF_1_224p_shot_1291
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-20_-_13-30_Chievo_0_-_1_Inter_1_224p_shot_2463
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Barcelona_2_-_1_Las_Palmas_1_224p_shot_2209
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_17-00_Manchester_United_3_-_0_Sunderland_2_224p_shot_2598
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-09-26_-_21-45_Napoli_2_-_1_Juventus_2_224p_shot_1270
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-03_-_17-00_Manchester_City_6_-_1_Newcastle_Utd_2_224p_shot_1309
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-17_-_17-00_Chelsea_2_-_0_Aston_Villa_1_224p_shot_2001
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-24_-_16-30_Bayern_Munich_4_-_0_FC_Koln_1_224p_shot_2394
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-10-24_-_17-00_West_Ham_2_-_1_Chelsea_2_224p_shot_2528
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_1_224p_shot_1037
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_B._Monchengladbach_1_-_1_Juventus_2_224p_shot_62
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_Real_Madrid_1_-_0_Paris_SG_2_224p_shot_1957
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-03_-_22-45_Shakhtar_Donetsk_4_-_0_Malmo_FF_1_224p_shot_384
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-07_-_20-30_Stoke_City_1_-_0_Chelsea_2_224p_shot_1186
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-21_-_20-15_Real_Madrid_0_-_4_Barcelona_2_224p_shot_2579
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-24_-_22-45_Barcelona_6_-_1_AS_Roma_1_224p_shot_1027
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_20-00_CSKA_Moscow_0_-_2_Wolfsburg_2_224p_shot_2885
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-11-25_-_22-45_B._Monchengladbach_4_-_2_Sevilla_1_224p_shot_2502
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-12_-_17-30_Bayern_Munich_2_-_0_Ingolstadt_2_224p_shot_1163
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-19_-_18-00_Chelsea_3_-_1_Sunderland_2_224p_shot_647
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2015-12-30_-_18-00_Real_Madrid_3_-_1_Real_Sociedad_1_224p_shot_949
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-13_-_18-00_Real_Madrid_4_-_2_Ath_Bilbao_2_224p_shot_2192
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-02-21_-_18-00_Malaga_1_-_1_Real_Madrid_1_224p_shot_167
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-03-19_-_18-00_Chelsea_2_-_2_West_Ham_2_224p_shot_949
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-09_-_17-00_Real_Madrid_4_-_0_Eibar_2_224p_shot_271
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-04-16_-_17-00_Getafe_1_-_5_Real_Madrid_2_224p_shot_820
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-08-28_-_21-45_Cagliari_2_-_2_AS_Roma_2_224p_shot_1496
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-17_-_17-00_Hull_City_1_-_4_Arsenal_2_224p_shot_2220
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-09-21_-_21-45_AS_Roma_4_-_0_Crotone_2_224p_shot_1916
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-01_-_19-30_Bayer_Leverkusen_2_-_0_Dortmund_2_224p_shot_2119
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-23_-_21-45_AS_Roma_4_-_1_Palermo_1_224p_shot_1837
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-28_-_21-45_Lille_0_-_1_Paris_SG_1_224p_shot_1275
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-29_-_19-30_Crystal_Palace_2_-_4_Liverpool_2_224p_shot_716
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-10-30_-_17-00_Empoli_0_-_0_AS_Roma_2_224p_shot_1503
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-05_-_17-30_Hamburger_SV_2_-_5_Dortmund_2_224p_shot_164
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-26_-_18-00_Liverpool_2_-_0_Sunderland_1_224p_shot_143
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-11-30_-_23-00_Paris_SG_2_-_0_Angers_2_224p_shot_2300
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-03_-_19-00_Montpellier_3_-_0_Paris_SG_2_224p_shot_138
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-10_-_20-30_Leicester_4_-_2_Manchester_City_2_224p_shot_2175
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-12_-_23-00_AS_Roma_1_-_0_AC_Milan_1_224p_shot_1155
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-16_-_22-30_Hoffenheim_2_-_2_Dortmund_2_224p_shot_167
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2016-12-27_-_20-15_Liverpool_4_-_1_Stoke_City_1_224p_shot_1858
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-08_-_22-45_Villarreal_1_-_1_Barcelona_1_224p_shot_433
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-15_-_17-00_Napoli_3_-_1_Pescara_2_224p_shot_648
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-21_-_18-15_Real_Madrid_2_-_1_Malaga_2_224p_shot_1157
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-01-22_-_22-45_AS_Roma_1_-_0_Cagliari_2_224p_shot_1386
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-04_-_22-45_Bologna_1_-_7_Napoli_2_224p_shot_122
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-10_-_22-45_Napoli_2_-_0_Genoa_1_224p_shot_1174
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-11_-_17-30_Darmstadt_2_-_1_Dortmund_2_224p_shot_2475
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-15_-_22-45_Real_Madrid_3_-_1_Napoli_2_224p_shot_2025
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-19_-_20-00_AS_Roma_4_-_1_Torino_2_224p_shot_410
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-26_-_18-15_Atl._Madrid_1_-_2_Barcelona_1_224p_shot_894
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-02-26_-_23-00_Marseille_1_-_5_Paris_SG_2_224p_shot_533
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-01_-_21-30_Barcelona_6_-_1_Gijon_1_224p_shot_1564
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-04_-_19-00_Paris_SG_1_-_0_Nancy_2_224p_shot_425
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-03-12_-_17-00_Napoli_3_-_0_Crotone_2_224p_shot_2543
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-02_-_21-45_Napoli_1_-_1_Juventus_2_224p_shot_47
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-09_-_21-45_Lazio_0_-_3_Napoli_2_224p_shot_898
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-15_-_16-00_AS_Roma_1_-_1_Atalanta_2_224p_shot_249
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-15_-_21-45_Napoli_3_-_0_Udinese_2_224p_shot_562
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-22_-_18-00_Paris_SG_2_-_0_Montpellier_1_224p_shot_1691
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-04-26_-_21-45_Arsenal_1_-_0_Leicester_2_224p_shot_1144
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-20_-_19-00_Chievo_3_-_5_AS_Roma_2_224p_shot_865
# Etiqueta inválida o coeficiente no válido en ./Frames_Bons_Definitius_TM/2017-05-21_-_21-00_Malaga_0_-_2_Real_Madrid_2_224p_shot_225

# %%
image_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
def get_dataloaders(df, batch_size=32, split_ratio=0.8):
    dataset = GoalDataset(df, transform=image_transforms['train'])

    train_size = int(split_ratio * len(dataset))
    val_size = len(dataset) - train_size

    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    # Replace transforms for validation set
    val_dataset.dataset.transform = image_transforms['val']

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

    return train_loader, val_loader

# %%
class CoordConvLayer(nn.Module):
   def __init__(self, with_r=False):
       super(CoordConvLayer, self).__init__()
       self.with_r = with_r


   def forward(self, x):
       """
       Añade canales coordenados a la imagen.
       x: batch x channels x height x width
       retorna: batch x (channels + 2 or 3) x height x width
       """
       batch_size, _, height, width = x.size()
       device = x.device


       xx_channel = torch.linspace(-1, 1, steps=width, device=device).repeat(1, height, 1)
       yy_channel = torch.linspace(-1, 1, steps=height, device=device).repeat(1, width, 1).transpose(1, 2)


       xx_channel = xx_channel.expand(batch_size, 1, height, width)
       yy_channel = yy_channel.expand(batch_size, 1, height, width)


       ret = torch.cat([x, xx_channel, yy_channel], dim=1)


       if self.with_r:
           rr = torch.sqrt(xx_channel ** 2 + yy_channel ** 2)
           ret = torch.cat([ret, rr], dim=1)


       return ret


class ModelCNN(nn.Module):
   def __init__(self):
       super(ModelCNN, self).__init__()
       self.coordconv = CoordConvLayer()  
       self.conv1 = nn.Conv2d(5, 16, 3,padding=1)  
       self.pool = nn.MaxPool2d(2, 2)
       self.conv2 = nn.Conv2d(16, 32, 3,padding=1)
       self.fc1 = nn.Linear(100353, 128)
       self.fc2 = nn.Linear(128, 1)


   def forward(self, x,coeficient):
       x = self.coordconv(x)                       # Agrega los canales coordenados
       x = self.pool(F.relu(self.conv1(x)))       # 112x112
       x = self.pool(F.relu(self.conv2(x)))       # 56x56
       x = x.view(-1, 32 * 56 * 56)
       coeficient=coeficient.view(-1,1)
       x=torch.cat((x,coeficient), dim=1)
       x = F.relu(self.fc1(x))
       x = torch.sigmoid(self.fc2(x))
       return x

# %%
class CoordConvLayer(nn.Module):
   def __init__(self, with_r=False):
       super(CoordConvLayer, self).__init__()
       self.with_r = with_r


   def forward(self, x):
       """
       Añade canales coordenados a la imagen.
       x: batch x channels x height x width
       retorna: batch x (channels + 2 or 3) x height x width
       """
       batch_size, _, height, width = x.size()
       device = x.device


       xx_channel = torch.linspace(-1, 1, steps=width, device=device).repeat(1, height, 1)
       yy_channel = torch.linspace(-1, 1, steps=height, device=device).repeat(1, width, 1).transpose(1, 2)


       xx_channel = xx_channel.expand(batch_size, 1, height, width)
       yy_channel = yy_channel.expand(batch_size, 1, height, width)


       ret = torch.cat([x, xx_channel, yy_channel], dim=1)


       if self.with_r:
           rr = torch.sqrt(xx_channel ** 2 + yy_channel ** 2)
           ret = torch.cat([ret, rr], dim=1)


       return ret


class ModelCNN(nn.Module):
   def __init__(self):
       super(ModelCNN, self).__init__()
       self.coordconv = CoordConvLayer()  
       self.conv1 = nn.Conv2d(5, 16, 3,padding=1)  
       self.pool = nn.MaxPool2d(2, 2)
       self.conv2 = nn.Conv2d(16, 32, 3,padding=1)
       self.fc1 = nn.Linear(100353, 128)
       self.fc2 = nn.Linear(128, 1)


   def forward(self, x,coeficient):
       x = self.coordconv(x)                       # Agrega los canales coordenados
       x = self.pool(F.relu(self.conv1(x)))       # 112x112
       x = self.pool(F.relu(self.conv2(x)))       # 56x56
       x = x.view(-1, 32 * 56 * 56)
       coeficient=coeficient.view(-1,1)
       x=torch.cat((x,coeficient), dim=1)
       x = F.relu(self.fc1(x))
       x = torch.sigmoid(self.fc2(x))
       return x

# %%
class WeightedLoss(nn.Module):
    def __init__(self, image_size, sigma=1.0):
        super(WeightedLoss, self).__init__()
        self.image_size = image_size
        self.sigma = sigma
        self.register_buffer('gaussian_mask', self.create_gaussian_mask())

    def create_gaussian_mask(self):
        x = torch.arange(0, self.image_size[1]).float()
        y = torch.arange(0, self.image_size[0]).float()
        xx, yy = torch.meshgrid(y, x, indexing='ij')
        cx, cy = self.image_size[1] // 2, self.image_size[0] // 2
        distance = (xx - cx)**2 + (yy - cy)**2
        gaussian = torch.exp(-distance / (2 * self.sigma ** 2))
        return gaussian / gaussian.sum()

    def forward(self, output, target, input_image):

        B = output.shape[0]
        
        # Convertir imagen a escala de grises y aplicar máscara gaussiana
        with torch.no_grad():
            grayscale = input_image[:, :3].mean(dim=1)  # [B, H, W]
            importance = (grayscale * self.gaussian_mask).view(B, -1).sum(dim=1)  # [B]
            importance = importance / importance.sum()  # Normalizar importancia

        # Asegúrate de que output es probabilidad (por si se omite sigmoid accidentalmente)
        output = torch.clamp(output.view(-1), min=1e-7, max=1 - 1e-7)  # Evitar log(0)
        target = target.view(-1)

        # Usar BCE con salida ya en [0, 1]
        bce = F.binary_cross_entropy(output, target, reduction='none')  # [B]
        weighted_loss = (importance * bce).sum()

        return weighted_loss

# %%
def train(epoch, criterion, model, optimizer, loader,device):

    total_loss = 0.0

    model.train()

    for batch_idx, (data, target,coeficient) in enumerate(loader):

        optimizer.zero_grad()

        data, target,coeficient  = data.to(device), target.to(device), coeficient.to(device).float()

        output = model(data,coeficient)
        output = output.view(-1)  
        loss = criterion(output, target.float())
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(loader.dataset),
                100. * batch_idx / len(loader), loss.item()))


        total_loss += loss.item()  
    return total_loss / len(loader.dataset)

# %%
        
def validate(criterion, model, loader, device):
    val_loss = 0
    correct = 0
    expected_goal_all=[]

    model.eval()
    with torch.no_grad():
        for data, target, coeficient in loader:
            data, target, coeficient = data.to(device), target.to(device), coeficient.to(device).float()
            output = model(data,coeficient).view(-1)  
            loss = criterion(output, target.float())
            val_loss += loss.item()
            expected_goal=output.view(-1)
            expected_goal_all.append((expected_goal.cpu(), data))


            pred = (output >= 0.5).long()  # predicción binaria
            correct += pred.eq(target).sum().item()

    val_loss /= len(loader.dataset)
    accuracy = 100. * correct / len(loader.dataset)
    print(f'\nTest set: Average loss: {val_loss:.4f}, Accuracy: {correct}/{len(loader.dataset)} ({accuracy:.0f}%)\n')

    return val_loss, expected_goal_all

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
torch.backends.cudnn.benchmark = True
learning_rate = 1e-4
lambda_l2 = 1e-5
momentum = 0.5
epoch=10
torch.manual_seed(0)
model=ModelCNN()
model.to(device)
train_loader, val_loader = get_dataloaders(df, batch_size=32)
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=lambda_l2)
# Out:
# cuda

# %%
losses= {"train":[], "validate":[] }
losses = {"train": [], "val": [], "expected_goal":[]}

for epoch in range(100):

    train_loss = train(epoch, criterion, model, optimizer, train_loader, device)
    val_loss,expected_goals = validate(criterion, model, val_loader, device)
    losses["train"].append(train_loss)
    losses["val"].append(val_loss)
    expected_goal_tensors=[eg for eg, _ in expected_goals]
    all_expected_goals=torch.cat(expected_goal_tensors)
    mean_expected_goals=all_expected_goals.mean().item()
    losses["expected_goal"].append(mean_expected_goals)

plt.plot(losses["train"], label="training loss")
plt.plot(losses["val"], label="validation loss")

plt.legend()
plt.pause(0.000001)
plt.show()
# Out:
# Train Epoch: 0 [0/472 (0%)]	Loss: 0.681054
#
# Test set: Average loss: 0.0213, Accuracy: 105/118 (89%)
#
# Train Epoch: 1 [0/472 (0%)]	Loss: 0.612298
#
# Test set: Average loss: 0.0198, Accuracy: 105/118 (89%)
#
# Train Epoch: 2 [0/472 (0%)]	Loss: 0.587329
#
# Test set: Average loss: 0.0184, Accuracy: 105/118 (89%)
#
# Train Epoch: 3 [0/472 (0%)]	Loss: 0.562888
#
# Test set: Average loss: 0.0171, Accuracy: 105/118 (89%)
#
# Train Epoch: 4 [0/472 (0%)]	Loss: 0.515994
#
# Test set: Average loss: 0.0161, Accuracy: 105/118 (89%)
#
# Train Epoch: 5 [0/472 (0%)]	Loss: 0.446156
#
# Test set: Average loss: 0.0153, Accuracy: 105/118 (89%)
#
# Train Epoch: 6 [0/472 (0%)]	Loss: 0.386929
#
# Test set: Average loss: 0.0147, Accuracy: 105/118 (89%)
#
# Train Epoch: 7 [0/472 (0%)]	Loss: 0.357723
#
# Test set: Average loss: 0.0142, Accuracy: 105/118 (89%)
#
# Train Epoch: 8 [0/472 (0%)]	Loss: 0.468236
#
# Test set: Average loss: 0.0137, Accuracy: 105/118 (89%)
#
# Train Epoch: 9 [0/472 (0%)]	Loss: 0.351631
#
# Test set: Average loss: 0.0134, Accuracy: 105/118 (89%)
#
# Train Epoch: 10 [0/472 (0%)]	Loss: 0.374347
#
# Test set: Average loss: 0.0131, Accuracy: 105/118 (89%)
#
# Train Epoch: 11 [0/472 (0%)]	Loss: 0.362653
#
# Test set: Average loss: 0.0129, Accuracy: 105/118 (89%)
#
# Train Epoch: 12 [0/472 (0%)]	Loss: 0.357261
#
# Test set: Average loss: 0.0127, Accuracy: 105/118 (89%)
#
# Train Epoch: 13 [0/472 (0%)]	Loss: 0.351297
#
# Test set: Average loss: 0.0125, Accuracy: 105/118 (89%)
#
# Train Epoch: 14 [0/472 (0%)]	Loss: 0.384328
#
# Test set: Average loss: 0.0124, Accuracy: 105/118 (89%)
#
# Train Epoch: 15 [0/472 (0%)]	Loss: 0.423865
#
# Test set: Average loss: 0.0123, Accuracy: 105/118 (89%)
#
# Train Epoch: 16 [0/472 (0%)]	Loss: 0.332217
#
# Test set: Average loss: 0.0122, Accuracy: 105/118 (89%)
#
# Train Epoch: 17 [0/472 (0%)]	Loss: 0.332360
#
# Test set: Average loss: 0.0122, Accuracy: 105/118 (89%)
#
# Train Epoch: 18 [0/472 (0%)]	Loss: 0.342148
#
# Test set: Average loss: 0.0121, Accuracy: 105/118 (89%)
#
# Train Epoch: 19 [0/472 (0%)]	Loss: 0.383896
#
# Test set: Average loss: 0.0121, Accuracy: 105/118 (89%)
#
# Train Epoch: 20 [0/472 (0%)]	Loss: 0.268435
#
# Test set: Average loss: 0.0120, Accuracy: 105/118 (89%)
#
# Train Epoch: 21 [0/472 (0%)]	Loss: 0.375370
#
# Test set: Average loss: 0.0120, Accuracy: 105/118 (89%)
#
# Train Epoch: 22 [0/472 (0%)]	Loss: 0.432281
#
# Test set: Average loss: 0.0120, Accuracy: 105/118 (89%)
#
# Train Epoch: 23 [0/472 (0%)]	Loss: 0.220943
#
# Test set: Average loss: 0.0120, Accuracy: 105/118 (89%)
#
# Train Epoch: 24 [0/472 (0%)]	Loss: 0.443474
#
# Test set: Average loss: 0.0120, Accuracy: 105/118 (89%)
#
# Train Epoch: 25 [0/472 (0%)]	Loss: 0.333543
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 26 [0/472 (0%)]	Loss: 0.436122
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 27 [0/472 (0%)]	Loss: 0.419798
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 28 [0/472 (0%)]	Loss: 0.373229
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 29 [0/472 (0%)]	Loss: 0.255037
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 30 [0/472 (0%)]	Loss: 0.496579
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 31 [0/472 (0%)]	Loss: 0.541721
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 32 [0/472 (0%)]	Loss: 0.429681
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 33 [0/472 (0%)]	Loss: 0.494800
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 34 [0/472 (0%)]	Loss: 0.373569
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 35 [0/472 (0%)]	Loss: 0.364632
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 36 [0/472 (0%)]	Loss: 0.375952
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 37 [0/472 (0%)]	Loss: 0.376800
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 38 [0/472 (0%)]	Loss: 0.371659
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 39 [0/472 (0%)]	Loss: 0.323753
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 40 [0/472 (0%)]	Loss: 0.439008
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 41 [0/472 (0%)]	Loss: 0.509480
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 42 [0/472 (0%)]	Loss: 0.364786
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 43 [0/472 (0%)]	Loss: 0.510864
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 44 [0/472 (0%)]	Loss: 0.437316
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 45 [0/472 (0%)]	Loss: 0.439589
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 46 [0/472 (0%)]	Loss: 0.421393
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 47 [0/472 (0%)]	Loss: 0.433507
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 48 [0/472 (0%)]	Loss: 0.306291
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 49 [0/472 (0%)]	Loss: 0.382094
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 50 [0/472 (0%)]	Loss: 0.241857
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 51 [0/472 (0%)]	Loss: 0.445054
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 52 [0/472 (0%)]	Loss: 0.369496
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 53 [0/472 (0%)]	Loss: 0.422710
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 54 [0/472 (0%)]	Loss: 0.384507
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 55 [0/472 (0%)]	Loss: 0.374998
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 56 [0/472 (0%)]	Loss: 0.435476
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 57 [0/472 (0%)]	Loss: 0.249847
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 58 [0/472 (0%)]	Loss: 0.355187
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 59 [0/472 (0%)]	Loss: 0.187487
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 60 [0/472 (0%)]	Loss: 0.312565
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 61 [0/472 (0%)]	Loss: 0.375061
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 62 [0/472 (0%)]	Loss: 0.374695
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 63 [0/472 (0%)]	Loss: 0.248488
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 64 [0/472 (0%)]	Loss: 0.363735
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 65 [0/472 (0%)]	Loss: 0.488907
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 66 [0/472 (0%)]	Loss: 0.253455
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 67 [0/472 (0%)]	Loss: 0.499843
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 68 [0/472 (0%)]	Loss: 0.306369
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 69 [0/472 (0%)]	Loss: 0.192704
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 70 [0/472 (0%)]	Loss: 0.377280
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 71 [0/472 (0%)]	Loss: 0.127566
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 72 [0/472 (0%)]	Loss: 0.434712
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 73 [0/472 (0%)]	Loss: 0.427384
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 74 [0/472 (0%)]	Loss: 0.194237
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 75 [0/472 (0%)]	Loss: 0.309123
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 76 [0/472 (0%)]	Loss: 0.315729
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 77 [0/472 (0%)]	Loss: 0.315075
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 78 [0/472 (0%)]	Loss: 0.242890
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 79 [0/472 (0%)]	Loss: 0.313979
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 80 [0/472 (0%)]	Loss: 0.556880
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 81 [0/472 (0%)]	Loss: 0.431223
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 82 [0/472 (0%)]	Loss: 0.248616
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 83 [0/472 (0%)]	Loss: 0.374633
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 84 [0/472 (0%)]	Loss: 0.427555
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 85 [0/472 (0%)]	Loss: 0.489035
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 86 [0/472 (0%)]	Loss: 0.309103
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 87 [0/472 (0%)]	Loss: 0.425419
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 88 [0/472 (0%)]	Loss: 0.249232
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 89 [0/472 (0%)]	Loss: 0.489898
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 90 [0/472 (0%)]	Loss: 0.379540
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 91 [0/472 (0%)]	Loss: 0.376456
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 92 [0/472 (0%)]	Loss: 0.301685
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 93 [0/472 (0%)]	Loss: 0.372362
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 94 [0/472 (0%)]	Loss: 0.370098
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 95 [0/472 (0%)]	Loss: 0.314808
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 96 [0/472 (0%)]	Loss: 0.495025
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 97 [0/472 (0%)]	Loss: 0.543572
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 98 [0/472 (0%)]	Loss: 0.502723
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)
#
# Train Epoch: 99 [0/472 (0%)]	Loss: 0.369326
#
# Test set: Average loss: 0.0119, Accuracy: 105/118 (89%)

# %%
plt.plot(losses["expected_goal"], label="expected_goal")
plt.xlabel("Epochs")
plt.plot
plt.legend()
plt.pause(0.000001)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

def denormalize(tensor_img, mean, std):
    device = tensor_img.device  # Asegura que todo se mantenga en el mismo dispositivo
    mean = torch.tensor(mean, device=device).view(-1, 1, 1)
    std = torch.tensor(std, device=device).view(-1, 1, 1)
    return tensor_img * std + mean


def plot_images_with_goals(expected_goal_all, n=6):
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]

    # Convertir expected_goal_all (batches) a lista plana de (eg, img)
    all_pairs = []
    for eg_batch, img_batch in expected_goal_all:
        for eg, img in zip(eg_batch, img_batch):
            all_pairs.append((eg, img))

    # Elegir n pares aleatorios sin repetición
    sampled_pairs = random.sample(all_pairs, k=min(n, len(all_pairs)))

    fig, axes = plt.subplots(1, len(sampled_pairs), figsize=(15,5))
    if len(sampled_pairs) == 1:
        axes = [axes]  # asegurar que axes es iterable si n=1

    for ax, (eg, img) in zip(axes, sampled_pairs):
        img = denormalize(img.clone(), mean, std)
        img_np = img.permute(1, 2, 0).cpu().numpy()
        img_np = img_np.clip(0, 1)
        ax.imshow(img_np)
        ax.set_title(f"Expected goal: {eg.item():.3f}")
        ax.axis('off')

    plt.show()

plot_images_with_goals(expected_goals, n=2)
